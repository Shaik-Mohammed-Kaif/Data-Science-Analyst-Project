# %% [markdown]
# # 02 — EV Deep EDA Analysis
# ### Electric Vehicle Population Data | Professional Exploratory Data Analysis
#
# **Workflow:** Univariate → Bivariate → Multivariate → Time → Geography → Vehicle → Range/MSRP → CAFV → Relationships → Business Insights
#
# > This notebook expects a DataFrame named `df` from Notebook 01. It can also load the cleaned CSV from the project folders.

# %%
# 1. EDA environment
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")

print("✅ EDA environment ready.")
# Out:
# ✅ EDA environment ready.

# %%
# 2. Load cleaned EV dataset

from pathlib import Path
import pandas as pd

# Project root
PROJECT_ROOT = Path.cwd().parent

# Cleaned dataset
file_path = PROJECT_ROOT / "datas" / "cleaned" / "ev_cleaned.csv"

# Check file
if not file_path.exists():
    raise FileNotFoundError(
        f"CSV not found at:\n{file_path}\n\n"
        "Expected location:\n"
        "D:/ev_project_v2-Data Analysis/datas/cleaned/ev_cleaned.csv"
    )

# Load dataset
df = pd.read_csv(file_path)

print("✅ Dataset loaded successfully")
print("File:", file_path)
print("Shape:", df.shape)

display(df.head())
# Out:
# ✅ Dataset loaded successfully
# File: D:\ev_project_v2-Data Analysis\datas\cleaned\ev_cleaned.csv
# Shape: (150482, 17)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6760\2544206632.py:21: DtypeWarning: Columns (0: Postal_Code, 1: Census_Tract) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#           VIN    County      City State Postal_Code  Model_Year     Make  \
# 0  KM8K33AGXL      King   Seattle    WA   98,103.00        2020  HYUNDAI
# 1  1C4RJYB61N      King   Bothell    WA   98,011.00        2022     JEEP
# 2  1C4RJYD61P    Yakima    Yakima    WA   98,908.00        2023     JEEP
# 3  5YJ3E1EA7J      King  Kirkland    WA   98,034.00        2018    TESLA
# 4  WBY7Z8C5XJ  Thurston   Olympia    WA   98,501.00        2018      BMW
#
#             Model                                 EV_Type  \
# 0            KONA          Battery Electric Vehicle (BEV)
# 1  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# ...

# %% [markdown]
# ## 1. Dataset Readiness

# %%
# 3. Shape
print(f"Rows: {len(df):,}")
print(f"Columns: {df.shape[1]:,}")
# Out:
# Rows: 150,482
# Columns: 17

# %%
# 4. Data types
display(df.dtypes.to_frame("dtype"))
# Out:
#                        dtype
# VIN                      str
# County                   str
# City                     str
# State                    str
# Postal_Code           object
# Model_Year             int64
# Make                     str
# Model                    str
# EV_Type                  str
# CAFV_Eligibility         str
# Electric_Range         int64
# Base_MSRP              int64
# Vehicle_ID             int64
# Vehicle_Location         str
# Electric_Utility         str
# Census_Tract          object
# Legislative_District   int64

# %%
# 5. Missing values
display(pd.DataFrame({
    "missing": df.isna().sum(),
    "missing_pct": (df.isna().mean()*100).round(2)
}).sort_values("missing_pct", ascending=False))
# Out:
#                       missing  missing_pct
# VIN                         0         0.00
# County                      0         0.00
# City                        0         0.00
# State                       0         0.00
# Postal_Code                 0         0.00
# Model_Year                  0         0.00
# Make                        0         0.00
# Model                       0         0.00
# EV_Type                     0         0.00
# CAFV_Eligibility            0         0.00
# Electric_Range              0         0.00
# Base_MSRP                   0         0.00
# Vehicle_ID                  0         0.00
# Vehicle_Location            0         0.00
# Electric_Utility            0         0.00
# Census_Tract                0         0.00
# Legislative_District        0         0.00

# %%
# 6. Duplicate records
print("Duplicate rows:", df.duplicated().sum())
print("Duplicate %:", round(df.duplicated().mean()*100, 2))
# Out:
# Duplicate rows: 0
# Duplicate %: 0.0

# %%
# 7. Cardinality / uniqueness
display(pd.DataFrame({
    "unique_count": df.nunique(dropna=False),
    "unique_pct": (df.nunique(dropna=False)/len(df)*100).round(2)
}).sort_values("unique_count", ascending=False))
# Out:
#                       unique_count  unique_pct
# Vehicle_ID                  150482      100.00
# VIN                           9529        6.33
# Census_Tract                  3658        2.43
# Postal_Code                   1292        0.86
# Vehicle_Location               822        0.55
# City                           683        0.45
# County                         183        0.12
# Model                          127        0.08
# Electric_Range                 102        0.07
# Electric_Utility                76        0.05
# Legislative_District            49        0.03
# State                           41        0.03
# Make                            37        0.02
# Base_MSRP                       31        0.02
# Model_Year                      22        0.01
# CAFV_Eligibility                 3        0.00
# EV_Type                          2        0.00

# %%
# 8. Numeric descriptive statistics
display(df.describe().T)
# Out:
#                           count           mean           std      min  \
# Model_Year           150,482.00       2,020.01          3.02 1,997.00
# Electric_Range       150,482.00          67.88         96.23     0.00
# Base_MSRP            150,482.00       1,312.64      9,231.31     0.00
# Vehicle_ID           150,482.00 211,112,233.35 81,963,879.64 4,385.00
# Legislative_District 150,482.00          29.35         14.81     1.00
#
#                                 25%            50%            75%  \
# Model_Year                 2,018.00       2,021.00       2,023.00
# Electric_Range                 0.00          18.00          97.00
# Base_MSRP                      0.00           0.00           0.00
# Vehicle_ID           169,347,305.25 215,030,630.00 239,911,895.50
# Legislative_District          18.00          33.00          43.00
#
#                                 max
# Model_Year                 2,024.00
# Electric_Range               337.00
# ...

# %%
# 9. Categorical descriptive statistics
cat_cols = df.select_dtypes(include=["object", "string", "category"]).columns
display(df[cat_cols].describe().T)
# Out:
#                       count   unique  \
# VIN                  150482     9529
# County               150482      183
# City                 150482      683
# State                150482       41
# Postal_Code      150,482.00 1,292.00
# Make                 150482       37
# Model                150482      127
# EV_Type              150482        2
# CAFV_Eligibility     150482        3
# Vehicle_Location     150482      822
# Electric_Utility     150482       76
# Census_Tract     150,482.00 3,658.00
#
#                                                                 top     freq
# VIN                                                      7SAYGDEE7P      807
# County                                                         King    79078
# City                                                        Seattle    25678
# State                                                            WA   150141
# Postal_Code                                               98,052.00 3,674.00
# ...

# %%
# 10. Memory usage
display((df.memory_usage(deep=True)/1024**2).sort_values(ascending=False).to_frame("memory_MB"))
# Out:
#                       memory_MB
# CAFV_Eligibility          15.14
# Electric_Utility          14.55
# EV_Type                   12.74
# Vehicle_Location          12.27
# VIN                        9.62
# City                       9.36
# Model                      9.09
# Make                       8.98
# County                     8.96
# State                      8.47
# Census_Tract               5.30
# Postal_Code                5.18
# Vehicle_ID                 1.15
# Model_Year                 1.15
# Electric_Range             1.15
# Base_MSRP                  1.15
# Legislative_District       1.15
# Index                      0.00

# %% [markdown]
# ## 2. Univariate Categorical Analysis

# %%
# 11. Reusable frequency + percentage function
def frequency_table(data, column, top_n=15):
    out = data[column].value_counts(dropna=False).head(top_n).rename("count").to_frame()
    out["percentage"] = (out["count"]/len(data)*100).round(2)
    return out

for col in ["State", "Make", "EV_Type", "CAFV_Eligibility"]:
    if col in df.columns:
        print(f"\n--- {col} ---")
        display(frequency_table(df, col))
# Out:
# --- State ---
#         count  percentage
# State
# WA     150141       99.77
# CA         92        0.06
# VA         35        0.02
# MD         33        0.02
# TX         20        0.01
# NC         13        0.01
# IL         12        0.01
# AZ         11        0.01
# CO         11        0.01
# FL          9        0.01
# NJ          9        0.01
# OR          8        0.01
# HI          8        0.01
# CT          7        0.00
# NY          7        0.00
# --- Make ---
#                count  percentage
# Make
# TESLA          68983       45.84
# NISSAN         13497        8.97
# CHEVROLET      12026        7.99
# FORD            7614        5.06
# BMW             6439        4.28
# KIA             6198        4.12
# TOYOTA          5223        3.47
# VOLKSWAGEN      4074        2.71
# VOLVO           3536        2.35
# JEEP            3292        2.19
# HYUNDAI         3171        2.11
# AUDI            3006        2.00
# CHRYSLER        2642        1.76
# ...

# %%
# 12. County distribution
if "County" in df.columns:
    display(frequency_table(df, "County", 20))
# Out:
#               count  percentage
# County
# King          79078       52.55
# Snohomish     17307       11.50
# Pierce        11542        7.67
# Clark          8855        5.88
# Thurston       5403        3.59
# Kitsap         4923        3.27
# Spokane        3690        2.45
# Whatcom        3668        2.44
# Benton         1801        1.20
# Skagit         1658        1.10
# Island         1640        1.09
# Clallam         920        0.61
# Jefferson       878        0.58
# Chelan          863        0.57
# San Juan        844        0.56
# Yakima          835        0.55
# Cowlitz         762        0.51
# Mason           706        0.47
# Lewis           598        0.40
# Grays Harbor    533        0.35

# %%
# 13. City distribution
if "City" in df.columns:
    display(frequency_table(df, "City", 20))
# Out:
#                count  percentage
# City
# Seattle        25678       17.06
# Bellevue        7691        5.11
# Redmond         5502        3.66
# Vancouver       5310        3.53
# Bothell         4861        3.23
# Kirkland        4622        3.07
# Sammamish       4436        2.95
# Renton          4043        2.69
# Olympia         3634        2.41
# Tacoma          3121        2.07
# Bellingham      2531        1.68
# Issaquah        2365        1.57
# Kent            2276        1.51
# Lynnwood        2210        1.47
# Spokane         2204        1.46
# Tukwila         2129        1.41
# Mercer Island   2083        1.38
# Everett         2043        1.36
# Woodinville     2024        1.35
# Snohomish       1740        1.16

# %%
# 14. Model distribution
if "Model" in df.columns:
    display(frequency_table(df, "Model", 25))
# Out:
#                 count  percentage
# Model
# MODEL Y         28502       18.94
# MODEL 3         27709       18.41
# LEAF            13187        8.76
# MODEL S          7611        5.06
# BOLT EV          5733        3.81
# MODEL X          5114        3.40
# VOLT             4890        3.25
# ID.4             2999        1.99
# NIRO             2876        1.91
# PACIFICA         2642        1.76
# WRANGLER         2629        1.75
# MUSTANG MACH-E   2619        1.74
# PRIUS PRIME      2527        1.68
# X5               2068        1.37
# I3               1917        1.27
# FUSION           1829        1.22
# EV6              1644        1.09
# IONIQ 5          1638        1.09
# C-MAX            1546        1.03
# RAV4 PRIME       1525        1.01
# R1T              1357        0.90
# XC90             1233        0.82
# BOLT EUV         1153        0.77
# E-GOLF           1075        0.71
# E-TRON            979        0.65

# %%
# 15. Electric utility distribution
if "Electric_Utility" in df.columns:
    display(frequency_table(df, "Electric_Utility", 20))
# Out:
#                                                     count  percentage
# Electric_Utility
# PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       55637       36.97
# PUGET SOUND ENERGY INC                              29865       19.85
# CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)        27268       18.12
# BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CL...   8643        5.74
# BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA...   6622        4.40
# PUGET SOUND ENERGY INC||PUD NO 1 OF WHATCOM COUNTY   3443        2.29
# BONNEVILLE POWER ADMINISTRATION||AVISTA CORP||I...   2244        1.49
# BONNEVILLE POWER ADMINISTRATION||PUD 1 OF SNOHO...   1341        0.89
# PACIFICORP                                           1102        0.73
# BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF BE...   1048        0.70
# MODERN ELECTRIC WATER COMPANY                         917        0.61
# PUD NO 1 OF CHELAN COUNTY                             863        0.57
# ...

# %%
# 16. Postal code distribution
if "Postal_Code" in df.columns:
    display(frequency_table(df, "Postal_Code", 20))
# Out:
#              count  percentage
# Postal_Code
# 98,052.00     3674        2.44
# 98,012.00     2512        1.67
# 98,033.00     2475        1.64
# 98,006.00     2399        1.59
# 98,004.00     2355        1.56
# 98,115.00     2264        1.50
# 98,040.00     2028        1.35
# 98,074.00     2011        1.34
# 98,188.00     2007        1.33
# 98,034.00     1983        1.32
# 98,072.00     1942        1.29
# 98,103.00     1773        1.18
# 98,075.00     1723        1.14
# 98,059.00     1592        1.06
# 98,110.00     1437        0.95
# 98,117.00     1429        0.95
# 98,501.00     1407        0.93
# 98,029.00     1361        0.90
# 98,021.00     1351        0.90
# 98,112.00     1303        0.87

# %% [markdown]
# ## 3. Univariate Numeric Analysis

# %%
# 17. Numeric columns
numeric_cols = df.select_dtypes(include=np.number).columns.tolist()
print(numeric_cols)
# Out:
# ['Model_Year', 'Electric_Range', 'Base_MSRP', 'Vehicle_ID', 'Legislative_District']

# %%
# 18. Mean / median / std / range
display(df[numeric_cols].agg(["count","mean","median","std","min","max"]).T)
# Out:
#                           count           mean         median           std  \
# Model_Year           150,482.00       2,020.01       2,021.00          3.02
# Electric_Range       150,482.00          67.88          18.00         96.23
# Base_MSRP            150,482.00       1,312.64           0.00      9,231.31
# Vehicle_ID           150,482.00 211,112,233.35 215,030,630.00 81,963,879.64
# Legislative_District 150,482.00          29.35          33.00         14.81
#
#                           min            max
# Model_Year           1,997.00       2,024.00
# Electric_Range           0.00         337.00
# Base_MSRP                0.00     845,000.00
# Vehicle_ID           4,385.00 479,254,772.00
# Legislative_District     1.00          49.00

# %%
# 19. Percentiles
display(df[numeric_cols].quantile([.01,.05,.25,.50,.75,.95,.99]).T)
# Out:
#                              0.01           0.05           0.25  \
# Model_Year               2,012.00       2,014.00       2,018.00
# Electric_Range               0.00           0.00           0.00
# Base_MSRP                    0.00           0.00           0.00
# Vehicle_ID           3,386,125.88 106,054,004.55 169,347,305.25
# Legislative_District         1.00           2.00          18.00
#
#                                0.50           0.75           0.95  \
# Model_Year                 2,021.00       2,023.00       2,023.00
# Electric_Range                18.00          97.00         266.00
# Base_MSRP                      0.00           0.00           0.00
# Vehicle_ID           215,030,630.00 239,911,895.50 349,070,631.55
# Legislative_District          33.00          43.00          48.00
#
#                                0.99
# Model_Year                 2,023.00
# Electric_Range               322.00
# Base_MSRP                 69,900.00
# ...

# %%
# 20. Skewness
display(df[numeric_cols].skew().sort_values(ascending=False).to_frame("skewness"))
# Out:
#                       skewness
# Base_MSRP                11.93
# Electric_Range            1.22
# Vehicle_ID                0.90
# Legislative_District     -0.49
# Model_Year               -0.98

# %%
# 21. Kurtosis
display(df[numeric_cols].kurt().sort_values(ascending=False).to_frame("kurtosis"))
# Out:
#                       kurtosis
# Base_MSRP               518.69
# Vehicle_ID                3.29
# Model_Year                0.24
# Electric_Range           -0.03
# Legislative_District     -1.06

# %%
# 22. Histograms
for col in numeric_cols:
    plt.figure(figsize=(8,4))
    plt.hist(df[col].dropna(), bins=30)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col); plt.ylabel("Frequency")
    plt.tight_layout(); plt.show()

# %%
# 23. Boxplots
for col in numeric_cols:
    plt.figure(figsize=(8,2.8))
    plt.boxplot(df[col].dropna(), vert=False)
    plt.title(f"Boxplot — {col}")
    plt.xlabel(col)
    plt.tight_layout(); plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6760\1622028671.py:4: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   plt.boxplot(df[col].dropna(), vert=False)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6760\1622028671.py:4: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   plt.boxplot(df[col].dropna(), vert=False)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6760\1622028671.py:4: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   plt.boxplot(df[col].dropna(), vert=False)
# ...

# %% [markdown]
# ## 4. Data Quality & Outlier Diagnostics

# %%
# 24. IQR outlier screening
rows = []
for col in numeric_cols:
    s = df[col].dropna()
    q1, q3 = s.quantile([.25,.75])
    iqr = q3-q1
    lo, hi = q1-1.5*iqr, q3+1.5*iqr
    count = ((df[col] < lo) | (df[col] > hi)).sum()
    rows.append([col,q1,q3,iqr,lo,hi,count,round(count/len(df)*100,2)])

display(pd.DataFrame(rows, columns=["column","Q1","Q3","IQR","lower","upper","outlier_count","outlier_pct"]))
# Out:
#                  column             Q1             Q3           IQR  \
# 0            Model_Year       2,018.00       2,023.00          5.00
# 1        Electric_Range           0.00          97.00         97.00
# 2             Base_MSRP           0.00           0.00          0.00
# 3            Vehicle_ID 169,347,305.25 239,911,895.50 70,564,590.25
# 4  Legislative_District          18.00          43.00         25.00
#
#           lower          upper  outlier_count  outlier_pct
# 0      2,010.50       2,030.50             60         0.04
# 1       -145.50         242.50          10073         6.69
# 2          0.00           0.00           3455         2.30
# 3 63,500,419.88 345,758,780.88          13268         8.82
# 4        -19.50          80.50              0         0.00

# %%
# 25. Zero values
display(pd.DataFrame({
    "zero_count": [(df[c]==0).sum() for c in numeric_cols],
    "zero_pct": [round((df[c]==0).mean()*100,2) for c in numeric_cols]
}, index=numeric_cols))
# Out:
#                       zero_count  zero_pct
# Model_Year                     0      0.00
# Electric_Range             69698     46.32
# Base_MSRP                 147027     97.70
# Vehicle_ID                     0      0.00
# Legislative_District           0      0.00

# %%
# 26. Negative values
display(pd.DataFrame({
    "negative_count": [(df[c]<0).sum() for c in numeric_cols],
    "negative_pct": [round((df[c]<0).mean()*100,2) for c in numeric_cols]
}, index=numeric_cols))
# Out:
#                       negative_count  negative_pct
# Model_Year                         0          0.00
# Electric_Range                     0          0.00
# Base_MSRP                          0          0.00
# Vehicle_ID                         0          0.00
# Legislative_District               0          0.00

# %% [markdown]
# ## 5. Model Year / Cohort Analysis

# %%
# 27. Model year frequency and percentage
if "Model_Year" in df.columns:
    yearly = df["Model_Year"].value_counts().sort_index().rename("vehicles").to_frame()
    yearly["percentage"] = (yearly["vehicles"]/len(df)*100).round(2)
    display(yearly)
# Out:
#             vehicles  percentage
# Model_Year
# 1997               1        0.00
# 1998               1        0.00
# 1999               4        0.00
# 2000               8        0.01
# 2002               2        0.00
# 2003               1        0.00
# 2008              19        0.01
# 2010              24        0.02
# 2011             796        0.53
# 2012            1633        1.09
# 2013            4566        3.03
# 2014            3613        2.40
# 2015            4934        3.28
# 2016            5650        3.75
# 2017            8574        5.70
# 2018           14441        9.60
# 2019           10717        7.12
# 2020           11294        7.51
# 2021           18684       12.42
# 2022           27799       18.47
# 2023           37079       24.64
# 2024             642        0.43

# %%
# 28. Model year trend
if "Model_Year" in df.columns:
    yearly = df.groupby("Model_Year").size()
    yearly.plot(figsize=(10,4), marker="o")
    plt.title("EV Population by Model Year")
    plt.xlabel("Model Year"); plt.ylabel("Vehicle Count")
    plt.grid(alpha=.2); plt.tight_layout(); plt.show()

# %%
# 29. Manufacturer × model year
if {"Make","Model_Year"}.issubset(df.columns):
    display(pd.crosstab(df["Model_Year"], df["Make"]).tail(15))
# Out:
# Make        ALFA ROMEO  AUDI  AZURE DYNAMICS  BENTLEY   BMW  CADILLAC  \
# Model_Year
# 2010                 0     0               0        0     0         0
# 2011                 0     0               5        0     0         0
# 2012                 0     0               4        0     0         0
# 2013                 0     0               0        0     0         0
# 2014                 0     0               0        0   450        57
# 2015                 0     0               0        0   392         0
# 2016                 0   212               0        0   376        20
# 2017                 0   189               0        0   677         3
# 2018                 0   173               0        0   727        12
# 2019                 0   443               0        0   317         0
# 2020                 0   225               0        0   157         0
# 2021                 0   551               0        1   647         0
# ...

# %% [markdown]
# ## 6. Vehicle Mix & Manufacturer Analysis

# %%
# 30. Manufacturer ranking
if "Make" in df.columns:
    make = df["Make"].value_counts().rename("vehicles").to_frame()
    make["share_pct"] = (make["vehicles"]/len(df)*100).round(2)
    display(make.head(25))
# Out:
#                vehicles  share_pct
# Make
# TESLA             68983      45.84
# NISSAN            13497       8.97
# CHEVROLET         12026       7.99
# FORD               7614       5.06
# BMW                6439       4.28
# KIA                6198       4.12
# TOYOTA             5223       3.47
# VOLKSWAGEN         4074       2.71
# VOLVO              3536       2.35
# JEEP               3292       2.19
# HYUNDAI            3171       2.11
# AUDI               3006       2.00
# CHRYSLER           2642       1.76
# RIVIAN             2483       1.65
# MERCEDES-BENZ      1054       0.70
# PORSCHE            1028       0.68
# MITSUBISHI          849       0.56
# HONDA               810       0.54
# FIAT                806       0.54
# MINI                791       0.53
# POLESTAR            764       0.51
# SUBARU              623       0.41
# SMART               274       0.18
# LINCOLN             229       0.15
# JAGUAR              228       0.15

# %%
# 31. EV type ranking
if "EV_Type" in df.columns:
    display(frequency_table(df, "EV_Type", 10))
# Out:
#                                          count  percentage
# EV_Type
# Battery Electric Vehicle (BEV)          116807       77.62
# Plug-in Hybrid Electric Vehicle (PHEV)   33675       22.38

# %%
# 32. Make × EV type
if {"Make","EV_Type"}.issubset(df.columns):
    display(pd.crosstab(df["Make"], df["EV_Type"]).sort_values(
        by=list(pd.crosstab(df["Make"], df["EV_Type"]).columns), ascending=False
    ).head(20))
# Out:
# EV_Type        Battery Electric Vehicle (BEV)  \
# Make
# TESLA                                   68983
# NISSAN                                  13497
# CHEVROLET                                7136
# KIA                                      4148
# VOLKSWAGEN                               4074
# FORD                                     3908
# HYUNDAI                                  2695
# RIVIAN                                   2483
# BMW                                      1796
# AUDI                                     1662
# VOLVO                                    1181
# FIAT                                      806
# MERCEDES-BENZ                             790
# POLESTAR                                  764
# MINI                                      579
# SUBARU                                    559
# PORSCHE                                   547
# SMART                                     274
# JAGUAR                                    228
# ...

# %%
# 33. EV type percentage within each manufacturer
if {"Make","EV_Type"}.issubset(df.columns):
    display(pd.crosstab(df["Make"], df["EV_Type"], normalize="index").mul(100).round(2).head(20))
# Out:
# EV_Type         Battery Electric Vehicle (BEV)  \
# Make
# ALFA ROMEO                                0.00
# AUDI                                     55.29
# AZURE DYNAMICS                          100.00
# BENTLEY                                   0.00
# BMW                                      27.89
# CADILLAC                                 47.73
# CHEVROLET                                59.34
# CHRYSLER                                  0.00
# FIAT                                    100.00
# FISKER                                    0.00
# FORD                                     51.33
# GENESIS                                 100.00
# HONDA                                     0.00
# HYUNDAI                                  84.99
# JAGUAR                                  100.00
# JEEP                                      0.00
# KIA                                      66.92
# LAND ROVER                                0.00
# LEXUS                                    39.13
# ...

# %%
# 34. Model ranking
if "Model" in df.columns:
    display(df["Model"].value_counts().head(30).to_frame("vehicles"))
# Out:
#                 vehicles
# Model
# MODEL Y            28502
# MODEL 3            27709
# LEAF               13187
# MODEL S             7611
# BOLT EV             5733
# MODEL X             5114
# VOLT                4890
# ID.4                2999
# NIRO                2876
# PACIFICA            2642
# WRANGLER            2629
# MUSTANG MACH-E      2619
# PRIUS PRIME         2527
# X5                  2068
# I3                  1917
# FUSION              1829
# EV6                 1644
# IONIQ 5             1638
# C-MAX               1546
# RAV4 PRIME          1525
# R1T                 1357
# XC90                1233
# BOLT EUV            1153
# E-GOLF              1075
# E-TRON               979
# XC60                 949
# PRIUS PLUG-IN        942
# XC40                 840
# R1S                  812
# 500                  806

# %% [markdown]
# ## 7. Geography Analysis

# %%
# 35. State ranking
if "State" in df.columns:
    state = df["State"].value_counts().rename("vehicles").to_frame()
    state["share_pct"] = (state["vehicles"]/len(df)*100).round(2)
    display(state.head(25))
# Out:
#        vehicles  share_pct
# State
# WA       150141      99.77
# CA           92       0.06
# VA           35       0.02
# MD           33       0.02
# TX           20       0.01
# NC           13       0.01
# IL           12       0.01
# AZ           11       0.01
# CO           11       0.01
# FL            9       0.01
# NJ            9       0.01
# OR            8       0.01
# HI            8       0.01
# CT            7       0.00
# NY            7       0.00
# NV            6       0.00
# SC            6       0.00
# DC            5       0.00
# GA            5       0.00
# MO            4       0.00
# NE            3       0.00
# KY            3       0.00
# AL            3       0.00
# LA            3       0.00
# MA            3       0.00

# %%
# 36. County ranking
if "County" in df.columns:
    county = df["County"].value_counts().rename("vehicles").to_frame()
    county["share_pct"] = (county["vehicles"]/len(df)*100).round(2)
    display(county.head(25))
# Out:
#               vehicles  share_pct
# County
# King             79078      52.55
# Snohomish        17307      11.50
# Pierce           11542       7.67
# Clark             8855       5.88
# Thurston          5403       3.59
# Kitsap            4923       3.27
# Spokane           3690       2.45
# Whatcom           3668       2.44
# Benton            1801       1.20
# Skagit            1658       1.10
# Island            1640       1.09
# Clallam            920       0.61
# Jefferson          878       0.58
# Chelan             863       0.57
# San Juan           844       0.56
# Yakima             835       0.55
# Cowlitz            762       0.51
# Mason              706       0.47
# Lewis              598       0.40
# Grays Harbor       533       0.35
# Franklin           511       0.34
# Kittitas           503       0.33
# Grant              452       0.30
# Walla Walla        360       0.24
# Douglas            296       0.20

# %%
# 37. City ranking
if "City" in df.columns:
    city = df["City"].value_counts().rename("vehicles").to_frame()
    city["share_pct"] = (city["vehicles"]/len(df)*100).round(2)
    display(city.head(25))
# Out:
#                    vehicles  share_pct
# City
# Seattle               25678      17.06
# Bellevue               7691       5.11
# Redmond                5502       3.66
# Vancouver              5310       3.53
# Bothell                4861       3.23
# Kirkland               4622       3.07
# Sammamish              4436       2.95
# Renton                 4043       2.69
# Olympia                3634       2.41
# Tacoma                 3121       2.07
# Bellingham             2531       1.68
# Issaquah               2365       1.57
# Kent                   2276       1.51
# Lynnwood               2210       1.47
# Spokane                2204       1.46
# Tukwila                2129       1.41
# Mercer Island          2083       1.38
# Everett                2043       1.36
# Woodinville            2024       1.35
# Snohomish              1740       1.16
# Gig Harbor             1672       1.11
# Shoreline              1641       1.09
# Auburn                 1632       1.08
# ...

# %%
# 38. State × EV type
if {"State","EV_Type"}.issubset(df.columns):
    display(pd.crosstab(df["State"], df["EV_Type"]).head(20))
# Out:
# EV_Type  Battery Electric Vehicle (BEV)  \
# State
# AK                                    1
# AL                                    3
# AP                                    1
# AR                                    2
# AZ                                    6
# BC                                    2
# CA                                   61
# CO                                    9
# CT                                    1
# DC                                    5
# DE                                    1
# FL                                    6
# GA                                    4
# HI                                    4
# ID                                    2
# IL                                    9
# IN                                    1
# KS                                    1
# KY                                    2
# LA                                    3
#
# EV_Type  Plug-in Hybrid Electric Vehicle (PHEV)
# State
# ...

# %%
# 39. State × Make
if {"State","Make"}.issubset(df.columns):
    display(df.groupby(["State","Make"]).size().sort_values(ascending=False).head(30).to_frame("vehicles"))
# Out:
#                      vehicles
# State Make
# WA    TESLA             68821
#       NISSAN            13481
#       CHEVROLET         12004
#       FORD               7592
#       BMW                6426
#       KIA                6187
#       TOYOTA             5196
#       VOLKSWAGEN         4064
#       VOLVO              3529
#       JEEP               3283
#       HYUNDAI            3165
#       AUDI               2998
#       CHRYSLER           2626
#       RIVIAN             2482
#       MERCEDES-BENZ      1053
#       PORSCHE            1027
#       MITSUBISHI          848
#       HONDA               808
#       FIAT                806
#       MINI                791
#       POLESTAR            763
#       SUBARU              622
#       SMART               274
#       LINCOLN             228
#       JAGUAR              228
#       LUCID               190
#       CADILLAC            175
#       LEXUS               138
#       MAZDA               136
# ...

# %%
# 40. Top-10 state concentration
if "State" in df.columns:
    print(f"Top 10 state share: {df['State'].value_counts(normalize=True).head(10).sum()*100:.2f}%")
# Out:
# Top 10 state share: 99.93%

# %% [markdown]
# ## 8. Electric Range & MSRP Analysis

# %%
# 41. Range summary
if "Electric_Range" in df.columns:
    display(df["Electric_Range"].describe().to_frame("Electric_Range"))
# Out:
#        Electric_Range
# count      150,482.00
# mean            67.88
# std             96.23
# min              0.00
# 25%              0.00
# 50%             18.00
# 75%             97.00
# max            337.00

# %%
# 42. Range by EV type
if {"EV_Type","Electric_Range"}.issubset(df.columns):
    display(df.groupby("EV_Type")["Electric_Range"].agg(["count","mean","median","min","max","std"]).sort_values("median",ascending=False))
# Out:
#                                          count  mean  median  min  max    std
# EV_Type
# Plug-in Hybrid Electric Vehicle (PHEV)   33675 30.66   26.00    6  153  16.46
# Battery Electric Vehicle (BEV)          116807 78.61    0.00    0  337 106.48

# %%
# 43. Range by manufacturer
if {"Make","Electric_Range"}.issubset(df.columns):
    display(df.groupby("Make")["Electric_Range"].agg(["count","mean","median"]).sort_values("median",ascending=False).head(25))
# Out:
#                       count   mean  median
# Make
# JAGUAR                  228 204.24  234.00
# WHEEGO ELECTRIC CARS      3 100.00  100.00
# TH!NK                     5 100.00  100.00
# FIAT                    806  85.63   87.00
# NISSAN                13497  84.72   84.00
# SMART                   274  62.38   58.00
# AZURE DYNAMICS            9  56.00   56.00
# CHEVROLET             12026  95.27   53.00
# HONDA                   810  46.63   47.00
# LEXUS                   138  22.52   37.00
# FISKER                   17  33.00   33.00
# ALFA ROMEO               12  33.00   33.00
# CHRYSLER               2642  32.24   32.00
# CADILLAC                176  19.08   31.00
# BMW                    6439  38.16   30.00
# KIA                    6198  52.62   26.00
# MAZDA                   136  26.00   26.00
# TOYOTA                 5223  26.92   25.00
# MITSUBISHI              849  29.78   22.00
# JEEP                   3292  22.33   21.00
# LINCOLN                 229  23.63   21.00
# ...

# %%
# 44. MSRP by EV type
if {"EV_Type","Base_MSRP"}.issubset(df.columns):
    display(df.groupby("EV_Type")["Base_MSRP"].agg(["count","mean","median","min","max"]).sort_values("median",ascending=False))
# Out:
#                                          count     mean  median  min     max
# EV_Type
# Battery Electric Vehicle (BEV)          116807 1,146.23    0.00    0  110950
# Plug-in Hybrid Electric Vehicle (PHEV)   33675 1,889.88    0.00    0  845000

# %%
# 45. MSRP by manufacturer
if {"Make","Base_MSRP"}.issubset(df.columns):
    display(df.groupby("Make")["Base_MSRP"].agg(["count","mean","median","min","max"]).sort_values("median",ascending=False).head(25))
# Out:
#                       count       mean     median     min     max
# Make
# FISKER                   17 102,000.00 102,000.00  102000  102000
# WHEEGO ELECTRIC CARS      3  32,995.00  32,995.00   32995   32995
# AZURE DYNAMICS            9       0.00       0.00       0       0
# AUDI                   3006       0.00       0.00       0       0
# ALFA ROMEO               12       0.00       0.00       0       0
# BMW                    6439   4,154.12       0.00       0   91250
# BENTLEY                   2       0.00       0.00       0       0
# CHRYSLER               2642   1,771.16       0.00       0   39995
# CADILLAC                176   6,400.14       0.00       0   75095
# FIAT                    806       0.00       0.00       0       0
# FORD                   7614       0.00       0.00       0       0
# GENESIS                 107       0.00       0.00       0       0
# CHEVROLET             12026       0.00       0.00       0       0
# ...

# %%
# 46. Range vs MSRP
if {"Electric_Range","Base_MSRP"}.issubset(df.columns):
    x = df[["Electric_Range","Base_MSRP"]].dropna()
    plt.figure(figsize=(8,5))
    plt.scatter(x["Electric_Range"], x["Base_MSRP"], alpha=.25)
    plt.title("Electric Range vs Base MSRP")
    plt.xlabel("Electric Range"); plt.ylabel("Base MSRP")
    plt.tight_layout(); plt.show()

# %% [markdown]
# ## 9. CAFV Eligibility Analysis

# %%
# 47. CAFV distribution
if "CAFV_Eligibility" in df.columns:
    display(frequency_table(df, "CAFV_Eligibility", 20))
# Out:
#                                                     count  percentage
# CAFV_Eligibility
# Eligibility unknown as battery range has not be...  69698       46.32
# Clean Alternative Fuel Vehicle Eligible             62951       41.83
# Not eligible due to low battery range               17833       11.85

# %%
# 48. CAFV × EV type
if {"CAFV_Eligibility","EV_Type"}.issubset(df.columns):
    display(pd.crosstab(df["CAFV_Eligibility"], df["EV_Type"]))
# Out:
# EV_Type                                             Battery Electric Vehicle (BEV)  \
# CAFV_Eligibility
# Clean Alternative Fuel Vehicle Eligible                                      47100
# Eligibility unknown as battery range has not be...                           69698
# Not eligible due to low battery range                                            9
#
# EV_Type                                             Plug-in Hybrid Electric Vehicle (PHEV)
# CAFV_Eligibility
# Clean Alternative Fuel Vehicle Eligible                                              15851
# Eligibility unknown as battery range has not be...                                       0
# Not eligible due to low battery range                                                17824

# %%
# 49. CAFV × manufacturer percentage
if {"CAFV_Eligibility","Make"}.issubset(df.columns):
    display(pd.crosstab(df["Make"], df["CAFV_Eligibility"], normalize="index").mul(100).round(2).head(25))
# Out:
# CAFV_Eligibility  Clean Alternative Fuel Vehicle Eligible  \
# Make
# ALFA ROMEO                                         100.00
# AUDI                                                21.62
# AZURE DYNAMICS                                     100.00
# BENTLEY                                              0.00
# BMW                                                 53.16
# CADILLAC                                            52.27
# CHEVROLET                                           73.58
# CHRYSLER                                           100.00
# FIAT                                               100.00
# FISKER                                             100.00
# FORD                                                 7.66
# GENESIS                                              0.00
# HONDA                                               98.89
# HYUNDAI                                             16.43
# JAGUAR                                              87.28
# ...

# %% [markdown]
# ## 10. Multivariate Relationships

# %%
# 50. Correlation matrix
corr = df[numeric_cols].corr(numeric_only=True)
display(corr.round(3))
# Out:
#                       Model_Year  Electric_Range  Base_MSRP  Vehicle_ID  \
# Model_Year                  1.00           -0.43      -0.23        0.06
# Electric_Range             -0.43            1.00       0.10       -0.05
# Base_MSRP                  -0.23            0.10       1.00       -0.02
# Vehicle_ID                  0.06           -0.05      -0.02        1.00
# Legislative_District       -0.01            0.02       0.01       -0.01
#
#                       Legislative_District
# Model_Year                           -0.01
# Electric_Range                        0.02
# Base_MSRP                             0.01
# Vehicle_ID                           -0.01
# Legislative_District                  1.00

# %%
# 51. Correlation heatmap
plt.figure(figsize=(8,6))
plt.imshow(corr, aspect="auto")
plt.colorbar(label="Correlation")
plt.xticks(range(len(corr.columns)), corr.columns, rotation=45, ha="right")
plt.yticks(range(len(corr.index)), corr.index)
plt.title("Numeric Feature Correlation Matrix")
plt.tight_layout(); plt.show()

# %%
# 52. Manufacturer × EV type × range
if {"Make","EV_Type","Electric_Range"}.issubset(df.columns):
    display(df.groupby(["Make","EV_Type"])["Electric_Range"]
            .agg(["count","mean","median"])
            .sort_values("count",ascending=False).head(40))
# Out:
#                                                       count   mean  median
# Make          EV_Type
# TESLA         Battery Electric Vehicle (BEV)          68983  90.30    0.00
# NISSAN        Battery Electric Vehicle (BEV)          13497  84.72   84.00
# CHEVROLET     Battery Electric Vehicle (BEV)           7136 129.47  238.00
# TOYOTA        Plug-in Hybrid Electric Vehicle (PHEV)   5034  26.71   25.00
# CHEVROLET     Plug-in Hybrid Electric Vehicle (PHEV)   4890  45.36   53.00
# BMW           Plug-in Hybrid Electric Vehicle (PHEV)   4643  41.02   30.00
# KIA           Battery Electric Vehicle (BEV)           4148  63.69    0.00
# VOLKSWAGEN    Battery Electric Vehicle (BEV)           4074  28.33    0.00
# FORD          Battery Electric Vehicle (BEV)           3908   5.04    0.00
#               Plug-in Hybrid Electric Vehicle (PHEV)   3706  21.44   19.00
# JEEP          Plug-in Hybrid Electric Vehicle (PHEV)   3292  22.33   21.00
# ...

# %%
# 53. Model year × range
if {"Model_Year","Electric_Range"}.issubset(df.columns):
    display(df.groupby("Model_Year")["Electric_Range"].agg(["count","mean","median"]).tail(20))
# Out:
#             count   mean  median
# Model_Year
# 1999            4  74.00   74.00
# 2000            8  58.00   58.00
# 2002            2  95.00   95.00
# 2003            1  95.00   95.00
# 2008           19 220.00  220.00
# 2010           24 226.88  245.00
# 2011          796  70.85   73.00
# 2012         1633  62.19   35.00
# 2013         4566  80.32   75.00
# 2014         3613  81.17   72.00
# 2015         4934  98.06   84.00
# 2016         5650 101.65   84.00
# 2017         8574 111.92   93.00
# 2018        14441 156.09  215.00
# 2019        10717 176.81  220.00
# 2020        11294 240.41  266.00
# 2021        18684  10.81    0.00
# 2022        27799   4.47    0.00
# 2023        37079   4.48    0.00
# 2024          642  17.68   21.00

# %%
# 54. Model year × MSRP
if {"Model_Year","Base_MSRP"}.issubset(df.columns):
    display(df.groupby("Model_Year")["Base_MSRP"].agg(["count","mean","median"]).tail(20))
# Out:
#             count       mean     median
# Model_Year
# 1999            4       0.00       0.00
# 2000            8       0.00       0.00
# 2002            2       0.00       0.00
# 2003            1       0.00       0.00
# 2008           19  98,950.00  98,950.00
# 2010           24 101,205.62 110,950.00
# 2011          796     958.54       0.00
# 2012         1633   5,977.10       0.00
# 2013         4566  11,849.01       0.00
# 2014         3613  12,904.32       0.00
# 2015         4934     171.26       0.00
# 2016         5650   2,333.64       0.00
# 2017         8574   1,159.27       0.00
# 2018        14441   2,503.65       0.00
# 2019        10717   1,894.67       0.00
# 2020        11294     136.44       0.00
# 2021        18684       0.00       0.00
# 2022        27799       0.00       0.00
# 2023        37079       0.00       0.00
# 2024          642       0.00       0.00

# %%
# 55. State × EV type percentage
if {"State","EV_Type"}.issubset(df.columns):
    display(pd.crosstab(df["State"],df["EV_Type"],normalize="index").mul(100).round(2).head(20))
# Out:
# EV_Type  Battery Electric Vehicle (BEV)  \
# State
# AK                               100.00
# AL                               100.00
# AP                               100.00
# AR                               100.00
# AZ                                54.55
# BC                               100.00
# CA                                66.30
# CO                                81.82
# CT                                14.29
# DC                               100.00
# DE                               100.00
# FL                                66.67
# GA                                80.00
# HI                                50.00
# ID                               100.00
# IL                                75.00
# IN                                50.00
# KS                                50.00
# KY                                66.67
# LA                               100.00
#
# EV_Type  Plug-in Hybrid Electric Vehicle (PHEV)
# State
# ...

# %% [markdown]
# ## 11. Identifier & Location Diagnostics

# %%
# 56. Identifier uniqueness
ids = [c for c in ["VIN","Vehicle_ID","Postal_Code","Census_Tract"] if c in df.columns]
display(pd.DataFrame({
    "unique_count": [df[c].nunique(dropna=True) for c in ids],
    "unique_pct": [round(df[c].nunique(dropna=True)/len(df)*100,2) for c in ids]
}, index=ids))
# Out:
#               unique_count  unique_pct
# VIN                   9529        6.33
# Vehicle_ID          150482      100.00
# Postal_Code           1292        0.86
# Census_Tract          3658        2.43

# %%
# 57. Duplicate identifiers
for col in ["VIN","Vehicle_ID"]:
    if col in df.columns:
        print(col, "duplicate rows:", df[col].duplicated().sum())
# Out:
# VIN duplicate rows: 140953
# Vehicle_ID duplicate rows: 0

# %%
# 58. Location completeness
location_cols = [c for c in ["County","City","State","Postal_Code","Vehicle_Location","Electric_Utility","Census_Tract"] if c in df.columns]
display(pd.DataFrame({
    "missing": [df[c].isna().sum() for c in location_cols],
    "missing_pct": [round(df[c].isna().mean()*100,2) for c in location_cols]
}, index=location_cols))
# Out:
#                   missing  missing_pct
# County                  0         0.00
# City                    0         0.00
# State                   0         0.00
# Postal_Code             0         0.00
# Vehicle_Location        0         0.00
# Electric_Utility        0         0.00
# Census_Tract            0         0.00

# %% [markdown]
# ## 12. Business-Oriented EDA Summary

# %%
# 59. Top categories
for col in ["Make","Model","State","City","EV_Type","CAFV_Eligibility"]:
    if col in df.columns:
        mode = df[col].mode()
        print(f"{col}: {mode.iloc[0] if not mode.empty else 'N/A'}")
# Out:
# Make: TESLA
# Model: MODEL Y
# State: WA
# City: Seattle
# EV_Type: Battery Electric Vehicle (BEV)
# CAFV_Eligibility: Eligibility unknown as battery range has not been researched

# %%
# 60. Compact analytical profile
profile = {
    "records": len(df),
    "columns": df.shape[1],
    "missing_cells": int(df.isna().sum().sum()),
    "duplicate_rows": int(df.duplicated().sum()),
    "numeric_columns": len(df.select_dtypes(include=np.number).columns),
    "categorical_columns": len(df.select_dtypes(include=["object","string","category"]).columns)
}
display(pd.Series(profile, name="value").to_frame())
# Out:
#                       value
# records              150482
# columns                  17
# missing_cells             0
# duplicate_rows            0
# numeric_columns           5
# categorical_columns      12

# %%
# 61. Top-5 percentage shares for major dimensions
for col in ["Make","State","EV_Type","CAFV_Eligibility"]:
    if col in df.columns:
        print(f"\n{col}")
        display(df[col].value_counts(normalize=True).head(5).mul(100).round(2).to_frame("share_pct"))
# Out:
# Make
#            share_pct
# Make
# TESLA          45.84
# NISSAN          8.97
# CHEVROLET       7.99
# FORD            5.06
# BMW             4.28
# State
#        share_pct
# State
# WA         99.77
# CA          0.06
# VA          0.02
# MD          0.02
# TX          0.01
# EV_Type
#                                         share_pct
# EV_Type
# Battery Electric Vehicle (BEV)              77.62
# Plug-in Hybrid Electric Vehicle (PHEV)      22.38
# CAFV_Eligibility
#                                                     share_pct
# CAFV_Eligibility
# Eligibility unknown as battery range has not be...      46.32
# Clean Alternative Fuel Vehicle Eligible                 41.83
# Not eligible due to low battery range                   11.85

# %%
# 62. Final numeric report
report = []
for col in numeric_cols:
    report.append({
        "column": col,
        "min": df[col].min(),
        "max": df[col].max(),
        "mean": df[col].mean(),
        "median": df[col].median(),
        "std": df[col].std(),
        "missing_pct": df[col].isna().mean()*100
    })
display(pd.DataFrame(report).round(2))
# Out:
#                  column   min        max           mean         median  \
# 0            Model_Year  1997       2024       2,020.01       2,021.00
# 1        Electric_Range     0        337          67.88          18.00
# 2             Base_MSRP     0     845000       1,312.64           0.00
# 3            Vehicle_ID  4385  479254772 211,112,233.35 215,030,630.00
# 4  Legislative_District     1         49          29.35          33.00
#
#             std  missing_pct
# 0          3.02         0.00
# 1         96.23         0.00
# 2      9,231.31         0.00
# 3 81,963,879.64         0.00
# 4         14.81         0.00

# %%
df.columns
# Out:
# Index(['VIN', 'County', 'City', 'State', 'Postal_Code', 'Model_Year', 'Make',
#        'Model', 'EV_Type', 'CAFV_Eligibility', 'Electric_Range', 'Base_MSRP',
#        'Vehicle_ID', 'Vehicle_Location', 'Electric_Utility', 'Census_Tract',
#        'Legislative_District'],
#       dtype='str')

# %%
df[['Model','Model_Year','Make','County','City','EV_Type','Electric_Range']].head(10)
# Out:
#             Model  Model_Year      Make     County         City  \
# 0            KONA        2020   HYUNDAI       King      Seattle
# 1  GRAND CHEROKEE        2022      JEEP       King      Bothell
# 2  GRAND CHEROKEE        2023      JEEP     Yakima       Yakima
# 3         MODEL 3        2018     TESLA       King     Kirkland
# 4              I3        2018       BMW   Thurston      Olympia
# 5         MODEL 3        2020     TESLA  Snohomish   Marysville
# 6        PACIFICA        2017  CHRYSLER       King         Kent
# 7         MODEL Y        2020     TESLA       King  Woodinville
# 8         MODEL 3        2018     TESLA     Island   Coupeville
# 9         MODEL Y        2023     TESLA       King     Bellevue
#
#                                   EV_Type  Electric_Range
# 0          Battery Electric Vehicle (BEV)             258
# 1  Plug-in Hybrid Electric Vehicle (PHEV)              25
# 2  Plug-in Hybrid Electric Vehicle (PHEV)              25
# ...

# %% [markdown]
# ## EV Launches Over Time (Real Trend)

# %%
yearly_launches = df.groupby("Model_Year").size()
plt.figure(figsize=(12,5))
yearly_launches.plot(kind="bar", color="#1f3864")
plt.title("Number of New Production EV Models Launched per Year (2010-2026)")
plt.ylabel("Models Launched")
plt.tight_layout()
plt.savefig("../outputs/figures/01_launches_per_year.png", dpi=150)
plt.show()

# %% [markdown]
# ## Market Split: Global vs. Chinese-Market EVs

# %%
# Market / State distribution
market_counts = df["State"].value_counts().head(10)

plt.figure(figsize=(8, 8))

market_counts.plot(
    kind="pie",
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Top 10 States by EV Records")
plt.ylabel("")

plt.tight_layout()

plt.savefig(
    "../outputs/figures/02_market_split.png",
    dpi=150,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Body Style Distribution

# %%
body_counts = df["Legislative_District"].value_counts().head(10)
plt.figure(figsize=(10,5))
body_counts.plot(kind="barh", color="#2a9d8f")
plt.title("Top 10 EV Body Styles (by model count)")
plt.xlabel("Number of Models")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.savefig("../outputs/figures/03_body_style_distribution.png", dpi=150)
plt.show()

# %% [markdown]
# ## Top Manufacturer Groups by Model Count

# %%
mfg_counts = df["Make"].value_counts().head(12)
plt.figure(figsize=(10,6))
mfg_counts.plot(kind="bar", color="#e76f51")
plt.title("Top 12 Manufacturer Groups by Number of EV Models")
plt.ylabel("Model Count")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.savefig("../outputs/figures/04_top_manufacturers.png", dpi=150)
plt.show()

# %% [markdown]
# ## Regional Origin Distribution

# %%
region_counts = df["Electric_Range"].value_counts()
plt.figure(figsize=(8,5))
region_counts.plot(kind="bar", color="#6a1b9a")
plt.title("EV Models by Region of Origin")
plt.ylabel("Model Count")
plt.tight_layout()
plt.savefig("../outputs/figures/05_region_distribution.png", dpi=150)
plt.show()

# %% [markdown]
# ## Dedicated BEV Platform Adoption Over Time
# Ek important real industry trend — kitne models purpose-built "dedicated" EV platforms pe hain (vs. converted ICE platforms).

# %%
# EV Type trend by Model Year
ev_type_trend = (
    df.dropna(subset=["Model_Year", "EV_Type"])
      .groupby(["Model_Year", "EV_Type"])
      .size()
      .unstack(fill_value=0)
)

# Convert counts to percentage
ev_type_pct = ev_type_trend.div(
    ev_type_trend.sum(axis=1),
    axis=0
).mul(100)

plt.figure(figsize=(12, 5))

for ev_type in ev_type_pct.columns:
    plt.plot(
        ev_type_pct.index,
        ev_type_pct[ev_type],
        marker="o",
        label=ev_type
    )

plt.title("EV Type Share by Model Year")
plt.xlabel("Model Year")
plt.ylabel("Share (%)")
plt.legend()
plt.grid(alpha=0.2)

plt.tight_layout()

plt.savefig(
    "../outputs/figures/06_ev_type_trend.png",
    dpi=150,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## SUV/Crossover Share Over Time
# Global auto industry trend — EVs bhi increasingly SUV/Crossover body style ki taraf shift ho rahe hain.

# %%
# Identify SUV / Crossover models from Model name
suv_keywords = r"SUV|Crossover|Cross|Sport Utility"

df["Is_SUV_Crossover"] = (
    df["Model"]
    .fillna("")
    .str.contains(suv_keywords, case=False, regex=True)
    .astype(int)
)

# SUV/Crossover share by Model Year
suv_trend = (
    df.dropna(subset=["Model_Year"])
      .groupby("Model_Year")["Is_SUV_Crossover"]
      .mean()
      .mul(100)
)

plt.figure(figsize=(12, 5))

suv_trend.plot(
    kind="line",
    marker="o"
)

plt.title("SUV/Crossover Share of EV Records by Model Year")
plt.xlabel("Model Year")
plt.ylabel("% SUV/Crossover")
plt.grid(alpha=0.2)

plt.tight_layout()

plt.savefig(
    "../outputs/figures/07_suv_share_trend.png",
    dpi=150,
    bbox_inches="tight"
)

plt.show()

# %%
model_counts = df["Model"].value_counts().head(20)

display(model_counts.to_frame("Vehicle_Count"))

plt.figure(figsize=(12, 7))

model_counts.sort_values().plot(
    kind="barh"
)

plt.title("Top 20 EV Models")
plt.xlabel("Number of Vehicles")
plt.ylabel("Model")

plt.tight_layout()
plt.show()
# Out:
#                 Vehicle_Count
# Model
# MODEL Y                 28502
# MODEL 3                 27709
# LEAF                    13187
# MODEL S                  7611
# BOLT EV                  5733
# MODEL X                  5114
# VOLT                     4890
# ID.4                     2999
# NIRO                     2876
# PACIFICA                 2642
# WRANGLER                 2629
# MUSTANG MACH-E           2619
# PRIUS PRIME              2527
# X5                       2068
# I3                       1917
# FUSION                   1829
# EV6                      1644
# IONIQ 5                  1638
# C-MAX                    1546
# RAV4 PRIME               1525

# %%
city_counts = df["City"].value_counts().head(20)

display(city_counts.to_frame("Vehicle_Count"))

plt.figure(figsize=(12, 6))

city_counts.sort_values().plot(
    kind="barh"
)

plt.title("Top 20 Cities by EV Vehicle Count")
plt.xlabel("Number of Vehicles")
plt.ylabel("City")

plt.tight_layout()
plt.show()
# Out:
#                Vehicle_Count
# City
# Seattle                25678
# Bellevue                7691
# Redmond                 5502
# Vancouver               5310
# Bothell                 4861
# Kirkland                4622
# Sammamish               4436
# Renton                  4043
# Olympia                 3634
# Tacoma                  3121
# Bellingham              2531
# Issaquah                2365
# Kent                    2276
# Lynnwood                2210
# Spokane                 2204
# Tukwila                 2129
# Mercer Island           2083
# Everett                 2043
# Woodinville             2024
# Snohomish               1740

# %%
ev_year = pd.crosstab(
    df["Model_Year"],
    df["EV_Type"]
)

display(ev_year)

ev_year.plot(
    kind="line",
    figsize=(12, 6),
    marker="o"
)

plt.title("EV Type Trend by Model Year")
plt.xlabel("Model Year")
plt.ylabel("Number of Vehicles")

plt.tight_layout()
plt.show()
# Out:
# EV_Type     Battery Electric Vehicle (BEV)  \
# Model_Year
# 1997                                     1
# 1998                                     1
# 1999                                     4
# 2000                                     8
# 2002                                     2
# 2003                                     1
# 2008                                    19
# 2010                                    21
# 2011                                   718
# 2012                                   776
# 2013                                  2927
# 2014                                  1796
# 2015                                  3625
# 2016                                  3867
# 2017                                  4466
# 2018                                 10046
# 2019                                  8772
# 2020                                  9617
# 2021                                 14998
# 2022                                 23511
# ...

# %% [markdown]
# ## Key EDA Observations
# 1. EV model launches ne 2020 ke baad sharp acceleration dikhayi hai — real market maturity signal.
# 2. Chinese market ab global model count ka bahut bada hissa hai — intense domestic competition.
# 3. Crossover SUV clearly dominant body style hai — poore industry trend ke saath consistent.
# 4. Dedicated BEV platforms ka adoption time ke saath badha hai — automakers converted-ICE platforms se purpose-built EV architecture ki taraf shift kar rahe hain.
# 5. Volkswagen Group, Stellantis, Geely Group, aur BYD sabse zyada models launch karne wale top manufacturer groups hain.

# %% [markdown]
# # Final EDA Interpretation Checklist
#
# Document these findings in your report:
#
# 1. Data quality and remaining anomalies
# 2. Dominant manufacturers
# 3. Dominant EV types
# 4. Geographic concentration
# 5. Model-year distribution
# 6. Most represented models
# 7. Electric-range distribution
# 8. MSRP distribution
# 9. Range–MSRP relationship
# 10. CAFV eligibility patterns
# 11. Important correlations
# 12. Business implications
#
# ### Important limitation
# This is a **vehicle-population dataset**. Do not call record counts "sales", "revenue", "profit", or true market share unless the dataset contains those measures.
#
# **Next:** statistical analysis / feature engineering.
